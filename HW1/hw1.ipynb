# %% [markdown]
# # 作业1：问卷+环境配置

# %% [markdown]
# ## 0. 说明

# %% [markdown]
# ### 0.1 关于 Jupyter Notebook

# %% [markdown]
# Jupyter Notebook 是一种可编程的文档类型，类似于 R Markdown。Jupyter Notebook 文档以一个个单元格组成，每个单元格可以是 Markdown 或者 Python 代码：前者通常用来写文字说明，后者用来运行代码。比如你双击第一行的标题，就会看到标题的 Markdown 代码（以 `#` 符号开头），再按 `Ctrl+Enter`，就会显示 Markdown 渲染的结果。

# %% [markdown]
# 而对于代码单元格， `Ctrl+Enter` 会执行单元格内的代码，例如用鼠标点击下面的单元格然后按键后会出现形如 `Out[x]` 的输出结果。

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %% [markdown]
# 我们的作业中既有需要说明的文字，又有需要编写的程序，前者用 Markdown 单元格，后者用代码单元格。单元格的类型可以在上方的下拉菜单中选择，也可以通过快捷键实现（通过菜单 Cell => Cell Type 查看）。

# %% [markdown]
# ### 0.2 关于 Markdown

# %% [markdown]
# Markdown 是常用的文档格式化语法，如果有不熟悉的，可以参考[这里](https://www.jianshu.com/p/335db5716248)的教程。需要说明的是 Jupyter Notebook 里可以插入数学公式，例如 $f(x)=\frac{1}{\sqrt{2\pi}}e^{-x^2/2}$。双击这个单元格来查看源代码。

# %% [markdown]
# ## 1. 练习

# %% [markdown]
# 1.1 请在下方插入一个 Markdown 单元格，输入一段文字，里面需包括斜体、粗体和列表格式。然后插入一张图片，图片地址使用相对路径，图片文件与 Notebook 一同上传。

# %% [markdown]
# ## 我的自我介绍
#
# 大家好，我是 **张三**（粗体），也可以叫我 *Xiao Ming*（斜体）。
#
# 我的兴趣爱好：
# - 编程
# - 阅读
# - 运动
#
# ![图片](photo.png)

# %% [markdown]
# 1.2 选取三个包含数学公式的定理，用 Markdown 格式在下方插入。

# %% [markdown]
# ### 三个数学定理
#
# **定理1（勾股定理）**：
# \[
# a^2 + b^2 = c^2
# \]
#
# **定理2（欧拉公式）**：
# \[
# e^{i\pi} + 1 = 0
# \]
#
# **定理3（二次方程求根公式）**：
# \[
# x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}
# \]

# %% [markdown]
# ## 2. 问卷

# %% [markdown]
# 思考并回答以下问题：

# %% [markdown]
# - 你现在对深度学习有多少了解？

# %% [markdown]
# 我现在对深度学习是初学者水平，刚刚开始接触。了解一些基本概念，比如神经网络由输入层、隐藏层、输出层组成，知道深度学习可以用来做图像识别、自然语言处理等任务。但具体原理和实现还不熟悉，希望通过这门课系统学习。

# %% [markdown]
# - 你预期今后的工作/研究与深度学习关联大吗？

# %% [markdown]
# 目前还不确定，因为我才刚开始接触深度学习。希望通过这门课的学习，了解自己是否对这个领域感兴趣，再决定未来的方向。如果学下来觉得有意思，可能会考虑往这个方向发展。

# %% [markdown]
# - 你喜欢/**不**喜欢的上课方式是怎样的？你想从这门课中学到什么？

# %% [markdown]
# 我喜欢的上课方式：
# 讲解清晰，节奏适中，适合初学者

# %% [markdown]
# - 你有哪些喜欢的获取知识的渠道（例如B站，知乎，技术博客，公众号等）？如果有请推荐一些，**具体到账号或网址**，不需要与本课程相关。回答仅作汇总使用，不会关联你的个人信息。

# %% [markdown]
# B站：有很多入门教程

# %% [markdown]
# - 你平时使用的 AI 工具有哪些？它们各自的使用场景是怎样的？

# %% [markdown]
# deepseek

# %% [markdown]
# - 你觉得 AI 的发展对自己未来可能有哪些影响？是正向的还是负向的？

# %% [markdown]
# 都有，方便但可能还会形成惰性

# %% [markdown]
# ## 2. 安装 PyTorch

# %% [markdown]
# 请参照课程文档《PyTorch安装》的提示配置好 PyTorch 环境。如果你的电脑具备 Nvidia 显卡，**优先尝试安装 GPU 版本**。用如下的代码验证 Conda 和 PyTorch 安装是否成功：

# %%
# !conda info
# Out:
# 5719.97s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
#      active environment : base
#     active env location : /opt/anaconda3
#             shell level : 1
#        user config file : /Users/yj/.condarc
#  populated config files : /opt/anaconda3/.condarc
#                           /opt/anaconda3/condarc.d/anaconda-auth.yml
#           conda version : 26.1.1
#     conda-build version : 25.11.1
#          python version : 3.13.9.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=m2
#                           __conda=26.1.1=0
#                           __osx=14.2.1=0
#                           __unix=0=0
#        base environment : /opt/anaconda3  (writable)
#       conda av data dir : /opt/anaconda3/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/osx-arm64
#                           https://repo.anaconda.com/pkgs/r/noarch
#           package cache : /opt/anaconda3/pkgs
#                           /Users/yj/.conda/pkgs
#        envs directories : /opt/anaconda3/envs
#                           /Users/yj/.conda/envs
#     temporary directory : /var/folders/p4/r0y565p16jlcgb16lxk_js_h0000gn/T
#                platform : osx-arm64
#              user-agent : conda/26.1.1 requests/2.32.5 CPython/3.13.9 Darwin/23.2.0 OSX/14.2.1 solver/libmamba conda-libmamba-solver/25.11.0 libmambapy/2.3.2 aau/0.7.5 c/. s/. e/.
#                 UID:GID : 501:20
#              netrc file : None
#            offline mode : False

# %%
# !pip3 install torch torchvision torchaudio
# Out:
# 6041.52s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Collecting torch
#   Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting torchvision
#   Downloading torchvision-0.26.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Collecting torchaudio
#   Downloading torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (6.9 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/anaconda3/lib/python3.13/site-packages (from torch) (2025.10.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.13/site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl (80.6 MB)
#    ━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.9/80.6 MB 52.9 kB/s eta 0:21:02
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (13.9 MB/80.6 MB, attempt 1)
# Resuming download torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl (13.9 MB/80.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 57.8 kB/s  0:20:45m0:00:0300:34
# Downloading torchvision-0.26.0-cp313-cp313-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 87.6 kB/s  0:00:23 eta 0:00:04
# Downloading torchaudio-2.11.0-cp313-cp313-macosx_12_0_arm64.whl (679 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.9/679.9 kB 350.8 kB/s  0:00:02eta 0:00:01
# Installing collected packages: torchaudio, torch, torchvision
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [torchvision] [torchvision]
# Successfully installed torch-2.11.0 torchaudio-2.11.0 torchvision-0.26.0

# %%
import torch
torch.manual_seed(123)
torch.randn(5, 3)
# Out:
# tensor([[-0.1115,  0.1204, -0.3696],
#         [-0.2404, -1.1969,  0.2093],
#         [-0.9724, -0.7550,  0.3239],
#         [-0.1085,  0.2103, -0.3908],
#         [ 0.2350,  0.6653,  0.3528]])

# %%
torch.cuda.is_available()
